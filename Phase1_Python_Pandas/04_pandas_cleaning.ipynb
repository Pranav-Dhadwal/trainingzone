# %% [markdown]
# # 04 Pandas Cleaning
#
# **Phase:** Phase1_Python_Pandas
# **Status:** 🔴 Not Started
# **Date Started:**
#
# ---
#
# ## Theory Notes
#
#
# ## Code Practice
#
#
# ## Key Takeaways

# %%
# Your code here
