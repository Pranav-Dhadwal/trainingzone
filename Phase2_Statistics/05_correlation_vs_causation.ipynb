# %% [markdown]
# # 05 Correlation Vs Causation
#
# **Phase:** Phase2_Statistics
# **Status:** 🔴 Not Started
# **Date Started:**
#
# ---
#
# ## Theory Notes
#
#
# ## Code Practice
#
#
# ## Key Takeaways

# %%
# Your code here
